# %% [markdown]
# # CausalNex Code
# - 데이터 전처리 방법 : 결측값 column 모두 삭제

# %% [markdown]
# ### CausalNex란 무엇인가?
# - Bayesian Networks(베이지안 네트워크)의 인과 추론을 위한 툴킷
# - 모델의 변수 간 관계를 그래프로 표현

# %% [markdown]
# for dirname, _, filenames in os.walk('/kaggle/input'):
#
# 이 코드 부분에서 오류가 발생함(이유는 찾는중...)
# ✔ 의문점 : 그냥 df에 파일을 불러오면 되는데 굳이 왜 /kaggle/input 이런식으로 했을까..?

# %%
"""import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import time


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))"""
# Out:
# "import numpy as np # linear algebra\nimport pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)\nimport matplotlib.pyplot as plt\nimport time\n\n\nimport os\nfor dirname, _, filenames in os.walk('/kaggle/input'):\n    for filename in filenames:\n        print(os.path.join(dirname, filename))"

# %%
"""df = pd.read_csv("/kaggle/input/uci-semcom/uci-secom.csv")"""
# Out:
# 'df = pd.read_csv("/kaggle/input/uci-semcom/uci-secom.csv")'

# %% [markdown]
# ## 1. 라이브러리 import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## 2. 데이터 불러오기

# %%
df = pd.read_csv("uci-secom.csv")

# %%
df.head()
# Out:
#                   Time        0        1          2          3       4      5  \
# 0  2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0
# 1  2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0
# 2  2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0
# 3  2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0
# 4  2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0
#
#           6       7       8  ...       581     582     583     584      585  \
# 0   97.6133  0.1242  1.5005  ...       NaN  0.5005  0.0118  0.0035   2.3630
# 1  102.3433  0.1247  1.4966  ...  208.2045  0.5019  0.0223  0.0055   4.4447
# 2   95.4878  0.1241  1.4436  ...   82.8602  0.4958  0.0157  0.0039   3.1745
# 3  104.2367  0.1217  1.4882  ...   73.8432  0.4990  0.0103  0.0025   2.0544
# 4  100.3967  0.1235  1.5031  ...       NaN  0.4800  0.4766  0.1045  99.3032
#
# ...

# %%
df.isna().mean()
# Out:
# Time         0.000000
# 0            0.003829
# 1            0.004467
# 2            0.008934
# 3            0.008934
#                ...
# 586          0.000638
# 587          0.000638
# 588          0.000638
# 589          0.000638
# Pass/Fail    0.000000
# Length: 592, dtype: float64

# %% [markdown]
# ## 3. 데이터 인덱싱
# - row의 경우에는 전체에 해당하고, column의 경우에는 제일 앞 줄인 Time 항목을 제외하고 0부터 마지막까지 인덱싱하여 df_feat에 저장

# %%
df_feat = df.iloc[:,1:-1]

# %%
df_feat
# Out:
#             0        1          2          3       4      5         6       7  \
# 0     3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0   97.6133  0.1242
# 1     3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 2     2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 3     2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
# 4     3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0  100.3967  0.1235
# ...       ...      ...        ...        ...     ...    ...       ...     ...
# 1562  2899.41  2464.36  2179.7333  3085.3781  1.4843  100.0   82.2467  0.1248
# 1563  3052.31  2522.55  2198.5667  1124.6595  0.8763  100.0   98.4689  0.1205
# 1564  2978.81  2379.78  2206.3000  1110.4967  0.8236  100.0   99.4122  0.1208
# 1565  2894.92  2532.01  2177.0333  1183.7287  1.5726  100.0   98.7978  0.1213
# 1566  2944.92  2450.76  2195.4444  2914.1792  1.5978  100.0   85.1011  0.1235
#
# ...

# %% [markdown]
# ## 4. 결측값 제거
# - dropna를 통해 결측값이 있는 column 삭제

# %%
df_feat.dropna(axis=1, inplace=True)

# %%
df_feat
# Out:
#           20      86      87         88     113  114       115     116  \
# 0     1.4026  2.3895  0.9690  1747.6049  0.9460  0.0  748.6115  0.9908
# 1     1.3825  2.3754  0.9894  1931.6464  0.9425  0.0  731.2517  0.9902
# 2     1.4123  2.4532  0.9880  1685.8514  0.9231  0.0  718.5777  0.9899
# 3     1.4011  2.4004  0.9904  1752.0968  0.9564  0.0  709.0867  0.9906
# 4     1.3888  2.4530  0.9902  1828.3846  0.9424  0.0  796.5950  0.9908
# ...      ...     ...     ...        ...     ...  ...       ...     ...
# 1562  1.4072  2.3762  0.9861  1869.4215  0.9520  0.0  727.6761  0.9894
# 1563  1.3949  2.4880  0.9911  1872.5133  0.9561  0.0  755.7527  0.9899
# 1564  1.4256  2.4590  0.9869  1820.3629  0.9488  0.0  704.2686  0.9891
# 1565  1.3868  2.3600  0.9796  1627.4714  0.9485  0.0  605.6190  0.9896
# 1566  1.4048  2.3701  0.9758  1759.9908  0.9432  0.0  683.5622  0.9893
#
#           117     119  ...     526     527       570     571    572     573  \
# ...
