# %% [markdown]
# # 5. UCI-SECOM(결측값 50% 제거/오버샘플링 X/로지스틱 회귀)

# %% [markdown]
# ### 📌 데이터 분석 과정
# - 데이터 전처리 : Null 값의 비율이 50%가 넘는 칼럼은 삭제하고 남은 결측값은 앞 또는 뒤 값을 가져옴
# - 스케일링: StandardScaler, PCA
# - 모델링 : Logistic Regression
# - 교차 검증 : cross_val_score
# - 평가 : confusion matrix, accuracy score, recall score, F1_score

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
import warnings
warnings.simplefilter("ignore")  #파이썬 경고 억제

# %%
dataset = pd.read_csv("uci-secom.csv") # 데이터 불러오기

# %%
dataset.head()  #데이터 확인
# Out:
#                   Time        0        1          2          3       4      5  \
# 0  2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0
# 1  2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0
# 2  2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0
# 3  2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0
# 4  2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0
#
#           6       7       8  ...       581     582     583     584      585  \
# 0   97.6133  0.1242  1.5005  ...       NaN  0.5005  0.0118  0.0035   2.3630
# 1  102.3433  0.1247  1.4966  ...  208.2045  0.5019  0.0223  0.0055   4.4447
# 2   95.4878  0.1241  1.4436  ...   82.8602  0.4958  0.0157  0.0039   3.1745
# 3  104.2367  0.1217  1.4882  ...   73.8432  0.4990  0.0103  0.0025   2.0544
# 4  100.3967  0.1235  1.5031  ...       NaN  0.4800  0.4766  0.1045  99.3032
#
#       586     587     588       589  Pass/Fail
# 0     NaN     NaN     NaN       NaN         -1
# 1  0.0096  0.0201  0.0060  208.2045         -1
# 2  0.0584  0.0484  0.0148   82.8602          1
# 3  0.0202  0.0149  0.0044   73.8432         -1
# 4  0.0202  0.0149  0.0044   73.8432         -1
#
# [5 rows x 592 columns]

# %%
dataset.isnull().any().any()  #Null 값 존재 여부 확인
# Out:
# True

# %% [markdown]
# ## 1. Data Processing

# %% [markdown]
# ### 1.1 결측값 처리

# %%
def null_values(dataset):
    nv=pd.concat([dataset.isnull().sum(), 100 * dataset.isnull().sum()/dataset.shape[0]],axis=1).rename(columns={0:'Missing_Records', 1:'Percentage (%)'})
    return nv[nv.Missing_Records>0].sort_values('Missing_Records', ascending=False)

# %%
dataset_na = null_values(dataset)
dataset_na
# Out:
#      Missing_Records  Percentage (%)
# 292             1429       91.193363
# 293             1429       91.193363
# 157             1429       91.193363
# 158             1429       91.193363
# 358             1341       85.577537
# ..               ...             ...
# 456                1        0.063816
# 218                1        0.063816
# 356                1        0.063816
# 457                1        0.063816
# 589                1        0.063816
#
# [538 rows x 2 columns]

# %%
dataset_na = dataset_na[dataset_na["Percentage (%)"] > 50]
dataset_na
# Out:
#      Missing_Records  Percentage (%)
# 292             1429       91.193363
# 293             1429       91.193363
# 157             1429       91.193363
# 158             1429       91.193363
# 358             1341       85.577537
# 85              1341       85.577537
# 492             1341       85.577537
# 220             1341       85.577537
# 518             1018       64.964901
# 246             1018       64.964901
# 245             1018       64.964901
# 516             1018       64.964901
# 517             1018       64.964901
# 110             1018       64.964901
# 384             1018       64.964901
# 382             1018       64.964901
# 383             1018       64.964901
# 109             1018       64.964901
# 244             1018       64.964901
# 111             1018       64.964901
# 580              949       60.561583
# 578              949       60.561583
# 581              949       60.561583
# 579              949       60.561583
# 73               794       50.670070
# 72               794       50.670070
# 345              794       50.670070
# 346              794       50.670070

# %%
dataset_na.shape
# Out:
# (28, 2)

# %%
dataset_na.index
# Out:
# Index(['292', '293', '157', '158', '358', '85', '492', '220', '518', '246',
#        '245', '516', '517', '110', '384', '382', '383', '109', '244', '111',
#        '580', '578', '581', '579', '73', '72', '345', '346'],
#       dtype='object')

# %%
dataset = dataset.drop(axis=1, columns=dataset_na.index)
dataset.shape
# Out:
# (1567, 564)

# %%
dataset.head()
# Out:
#                   Time        0        1          2          3       4      5  \
# 0  2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0
# 1  2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0
# 2  2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0
# 3  2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0
# 4  2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0
#
#           6       7       8  ...      577     582     583     584      585  \
# 0   97.6133  0.1242  1.5005  ...  14.9509  0.5005  0.0118  0.0035   2.3630
# 1  102.3433  0.1247  1.4966  ...  10.9003  0.5019  0.0223  0.0055   4.4447
# 2   95.4878  0.1241  1.4436  ...   9.2721  0.4958  0.0157  0.0039   3.1745
# 3  104.2367  0.1217  1.4882  ...   8.5831  0.4990  0.0103  0.0025   2.0544
# 4  100.3967  0.1235  1.5031  ...  10.9698  0.4800  0.4766  0.1045  99.3032
#
#       586     587     588       589  Pass/Fail
# 0     NaN     NaN     NaN       NaN         -1
# 1  0.0096  0.0201  0.0060  208.2045         -1
# 2  0.0584  0.0484  0.0148   82.8602          1
# 3  0.0202  0.0149  0.0044   73.8432         -1
# 4  0.0202  0.0149  0.0044   73.8432         -1
#
# [5 rows x 564 columns]

# %%
dataset.fillna(method='ffill', inplace=True)
dataset.fillna(method='bfill', inplace=True)
dataset
# Out:
#                      Time        0        1          2          3       4  \
# 0     2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602
# 1     2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294
# 2     2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102
# 3     2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204
# 4     2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334
# ...                   ...      ...      ...        ...        ...     ...
# 1562  2008-10-16 15:13:00  2899.41  2464.36  2179.7333  3085.3781  1.4843
# 1563  2008-10-16 20:49:00  3052.31  2522.55  2198.5667  1124.6595  0.8763
# 1564  2008-10-17 05:26:00  2978.81  2379.78  2206.3000  1110.4967  0.8236
# 1565  2008-10-17 06:01:00  2894.92  2532.01  2177.0333  1183.7287  1.5726
# 1566  2008-10-17 06:07:00  2944.92  2450.76  2195.4444  2914.1792  1.5978
#
#           5         6       7       8  ...      577     582     583     584  \
# 0     100.0   97.6133  0.1242  1.5005  ...  14.9509  0.5005  0.0118  0.0035
# 1     100.0  102.3433  0.1247  1.4966  ...  10.9003  0.5019  0.0223  0.0055
# 2     100.0   95.4878  0.1241  1.4436  ...   9.2721  0.4958  0.0157  0.0039
# 3     100.0  104.2367  0.1217  1.4882  ...   8.5831  0.4990  0.0103  0.0025
# 4     100.0  100.3967  0.1235  1.5031  ...  10.9698  0.4800  0.4766  0.1045
# ...     ...       ...     ...     ...  ...      ...     ...     ...     ...
# 1562  100.0   82.2467  0.1248  1.3424  ...  11.7256  0.4988  0.0143  0.0039
# 1563  100.0   98.4689  0.1205  1.4333  ...  17.8379  0.4975  0.0131  0.0036
# 1564  100.0   99.4122  0.1208  1.4333  ...  17.7267  0.4987  0.0153  0.0041
# 1565  100.0   98.7978  0.1213  1.4622  ...  19.2104  0.5004  0.0178  0.0038
# 1566  100.0   85.1011  0.1235  1.4622  ...  22.9183  0.4987  0.0181  0.0040
#
#           585     586     587     588       589  Pass/Fail
# 0      2.3630  0.0096  0.0201  0.0060  208.2045         -1
# 1      4.4447  0.0096  0.0201  0.0060  208.2045         -1
# 2      3.1745  0.0584  0.0484  0.0148   82.8602          1
# 3      2.0544  0.0202  0.0149  0.0044   73.8432         -1
# 4     99.3032  0.0202  0.0149  0.0044   73.8432         -1
# ...       ...     ...     ...     ...       ...        ...
# 1562   2.8669  0.0068  0.0138  0.0047  203.1720         -1
# 1563   2.6238  0.0068  0.0138  0.0047  203.1720         -1
# 1564   3.0590  0.0197  0.0086  0.0025   43.5231         -1
# 1565   3.5662  0.0262  0.0245  0.0075   93.4941         -1
# 1566   3.6275  0.0117  0.0162  0.0045  137.7844         -1
#
# [1567 rows x 564 columns]

# %%
null_values(dataset)
# Out:
# Empty DataFrame
# Columns: [Missing_Records, Percentage (%)]
# Index: []

# %%
dataset.shape
# Out:
# (1567, 564)

# %%
# nunique() 함수를 써서 5열의 고유치 개수를 확인
dataset["5"].nunique()
# Out:
# 1

# %%
# Column '5'와 같이 고유값이 1개인 열을 저장하는 unique_columns함수 생성
def unique_columns(df):
    uni_col_list = []
    for column in df.columns:
        if df[column].nunique() == 1:
            uni_col_list.append(column)
    return uni_col_list

# %%
# 고유치 개수가 1개인 열의 개수 확인
len(unique_columns(dataset))
# Out:
# 116

# %%
dataset.shape
# Out:
# (1567, 564)

# %%
dataset = dataset.drop(axis=1, columns=unique_columns(dataset))
dataset.shape
# Out:
# (1567, 448)

# %% [markdown]
# ### 1.2 데이터 분리

# %%
X = dataset.drop(['Pass/Fail','Time'],axis=1)  #Time과 Pass/Fail 칼럼 삭제한 값 X에 저장
y = dataset['Pass/Fail']  #Pass/Fail 칼럼만 y에 저장

print("shape of x:", X.shape)
print("shape of y:", y.shape)
# Out:
# shape of x: (1567, 446)
# shape of y: (1567,)

# %%
X.head()
# Out:
#          0        1          2          3       4         6       7       8  \
# 0  3030.93  2564.00  2187.7333  1411.1265  1.3602   97.6133  0.1242  1.5005
# 1  3095.78  2465.14  2230.4222  1463.6606  0.8294  102.3433  0.1247  1.4966
# 2  2932.61  2559.94  2186.4111  1698.0172  1.5102   95.4878  0.1241  1.4436
# 3  2988.72  2479.90  2199.0333   909.7926  1.3204  104.2367  0.1217  1.4882
# 4  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.3967  0.1235  1.5031
#
#         9      10  ...     576      577     582     583     584      585  \
# 0  0.0162 -0.0034  ...  1.6765  14.9509  0.5005  0.0118  0.0035   2.3630
# 1 -0.0005 -0.0148  ...  1.1065  10.9003  0.5019  0.0223  0.0055   4.4447
# 2  0.0041  0.0013  ...  2.0952   9.2721  0.4958  0.0157  0.0039   3.1745
# 3 -0.0124 -0.0033  ...  1.7585   8.5831  0.4990  0.0103  0.0025   2.0544
# 4 -0.0031 -0.0072  ...  1.6597  10.9698  0.4800  0.4766  0.1045  99.3032
#
#       586     587     588       589
# 0  0.0096  0.0201  0.0060  208.2045
# 1  0.0096  0.0201  0.0060  208.2045
# 2  0.0584  0.0484  0.0148   82.8602
# 3  0.0202  0.0149  0.0044   73.8432
# 4  0.0202  0.0149  0.0044   73.8432
#
# [5 rows x 446 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1096, 446)
# (1096,)
# (471, 446)
# (471,)

# %% [markdown]
# ### 1.3 데이터 스케일링

# %%
print('X_train의 평균값 ')
print(X_train.mean())

print('\nX_train의 분산값')
print(X_train.var())
# Out:
# X_train의 평균값
# 0      3014.985757
# 1      2496.266341
# 2      2200.700479
# 3      1396.309987
# 4         4.388848
#           ...
# 585       3.033240
# 586       0.021591
# 587       0.016588
# 588       0.005335
# 589     101.419564
# Length: 446, dtype: float64
#
# X_train의 분산값
# 0        5253.482351
# 1        6276.265861
# 2         863.097007
# 3      190937.548184
# 4        3376.135964
#            ...
# 585         9.510624
# 586         0.000156
# 587         0.000086
# 588         0.000009
# 589      9384.227474
# Length: 446, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
#StandardScaler 객체 생성
sc = StandardScaler()

#StandScaler로 데이터 세트 변환
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

X_sc = sc.fit_transform(X)

# %%
X_sc_pd = pd.DataFrame(X_sc)
X_sc_pd.head()  #표준화된 데이터 확인
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.225661  0.848549 -0.438248  0.030352 -0.050141 -0.553885  0.265085
# 1  1.106653 -0.382768  1.010742  0.149398 -0.059605  0.200866  0.321051
# 2 -1.110023  0.797981 -0.483128  0.680468 -0.047466 -0.893044  0.253892
# 3 -0.347765 -0.198930 -0.054692 -1.105709 -0.050851  0.502989 -0.014743
# 4  0.243458  0.087165  1.110687 -0.161373 -0.047053 -0.109747  0.186733
#
#         7         8         9    ...       436       437       438        439  \
# 0  0.510062  1.128800 -0.380965  ... -0.229797 -0.135520  0.117015  -0.204837
# 1  0.457237  0.023070 -1.607223  ... -0.263493 -0.460054  0.527813   0.406731
# 2 -0.260632  0.327643  0.124597  ... -0.205046 -0.590505 -1.262092   0.022317
# 3  0.343462 -0.764845 -0.370208  ... -0.224950 -0.645708 -0.323126  -0.292204
# 4  0.545278 -0.149079 -0.789718  ... -0.230791 -0.454486 -5.898239  26.867225
#
#          440        441       442       443       444       445
# 0  -0.093217  -0.197053 -0.959280  0.411568  0.249960  1.155458
# 1   0.444697   0.385118 -0.959280  0.411568  0.249960  1.155458
# 2   0.014366   0.029892  2.990884  3.626604  3.321193 -0.179810
# 3  -0.362173  -0.283356 -0.101252 -0.179181 -0.308446 -0.275866
# 4  27.071414  26.913331 -0.101252 -0.179181 -0.308446 -0.275866
#
# [5 rows x 446 columns]

# %%
#DataFrame 형태로 변경
X_train_sc_pd = pd.DataFrame(X_train_sc)
X_test_sc_pd = pd.DataFrame(X_test_sc)

# %%
print('X_train_sc의 평균값 ')
print(X_train_sc_pd.mean())

print('\nX_train_sc의 분산값')
print(X_train_sc_pd.var())
# Out:
# X_train_sc의 평균값
# 0     -6.111292e-15
# 1     -1.675059e-15
# 2      8.714846e-15
# 3     -1.537699e-16
# 4      1.948715e-17
#            ...
# 441   -5.358649e-17
# 442   -1.492369e-16
# 443    1.967202e-16
# 444   -1.547829e-16
# 445    3.646718e-18
# Length: 446, dtype: float64
#
# X_train_sc의 분산값
# 0      1.000913
# 1      1.000913
# 2      1.000913
# 3      1.000913
# 4      1.000913
#          ...
# 441    1.000913
# 442    1.000913
# 443    1.000913
# 444    1.000913
# 445    1.000913
# Length: 446, dtype: float64

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pca = PCA(n_components=0.85)
X_sc_pca = pca.fit_transform(X_sc)

X_sc_pca_pd = pd.DataFrame(data = X_sc_pca)

# %%
print('Variance of each component:', pca.explained_variance_ratio_)
print('\nTotal features:', pca.n_components_)
print('Total Variance Explained:', round(sum(list(pca.explained_variance_ratio_))*100, 2))
# Out:
# Variance of each component: [0.05726804 0.03859757 0.03002679 0.0270121  0.02196476 0.02083755
#  0.01928865 0.01892683 0.01716777 0.0153982  0.01401313 0.01377929
#  0.01337192 0.01328478 0.0124235  0.01207854 0.01187445 0.01157255
#  0.0110308  0.01080075 0.01050347 0.01033739 0.00997918 0.00993212
1.567000e+03  1.567000e+03  1.567000e+03  1.567000e+03  1.567000e+03
# mean  -2.713564e-17 -7.627027e-17  1.689778e-17 -1.551620e-17 -2.890689e-17
# std    1.077829e+00  1.070343e+00  1.063605e+00  1.054437e+00  1.052615e+00
# min   -4.557697e+00 -3.677055e+00 -4.667348e+00 -4.046119e+00 -5.381531e+00
# 25%   -6.884115e-01 -6.964983e-01 -6.574561e-01 -7.387902e-01 -6.610164e-01
# 50%   -6.412952e-03 -1.667646e-02  1.082921e-02 -1.501405e-02 -1.280110e-02
# 75%    6.540122e-01  7.011472e-01  6.530630e-01  7.231406e-01  6.544552e-01
# max    5.871356e+00  4.999072e+00  4.747863e+00  5.075104e+00  5.585031e+00
#
#                 104
# count  1.567000e+03
# mean   5.590083e-17
# std    1.035170e+00
# min   -3.570671e+00
# 25%   -6.712793e-01
# 50%    6.122087e-02
# 75%    6.762651e-01
# max    3.735398e+00
#
# [8 rows x 105 columns]

# %% [markdown]
# ## 2. Data Modeling

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score, roc_auc_score, precision_score, recall_score, f1_score

# %% [markdown]
# ### 2.1 교차검증

# %%
classifier = LogisticRegression(random_state=10)

score = cross_val_score(classifier, X_train_sc_pca, y_train, cv=10, n_jobs=-1, scoring='accuracy')

# %%
print('교차 검증별 정확도 : ', np.round(score,4))
print('평균 검증 정확도 : ', np.round(np.mean(score),4))
# Out:
# 교차 검증별 정확도 :  [0.8909 0.9    0.9182 0.9182 0.9182 0.8909 0.8899 0.8899 0.9083 0.9083]
# 평균 검증 정확도 :  0.9033

# %% [markdown]
# ### 2.2 평가지표

# %%
lr_clf = LogisticRegression()
lr_clf.fit(X_train_sc_pca, y_train)
lr_preds = lr_clf.predict(X_test_sc_pca)

# %%
print('confusion_matrix\n', confusion_matrix(lr_preds, y_test))
print('accuracy score : ', accuracy_score(lr_preds, y_test))
print('f1_score : ', f1_score(y_test,lr_preds))
print('recall_score : ', recall_score(lr_preds, y_test))
print('precision_score : ',precision_score(y_test,lr_preds))
print('roc_auc_score : ',roc_auc_score(y_test,lr_preds))
# Out:
# confusion_matrix
#  [[426  28]
#  [ 13   4]]
# accuracy score :  0.9129511677282378
# f1_score :  0.16326530612244897
# recall_score :  0.23529411764705882
# precision_score :  0.23529411764705882
# roc_auc_score :  0.5476936218678816

# %% [markdown]
# ### 2.3 하이퍼 파라미터

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'penalty':['l2','l1'], 'C':[0.01,0.1,1,1,5,10]}

# %%
grid_clf = GridSearchCV(lr_clf, param_grid=params, scoring='accuracy', cv=10)
grid_clf.fit(X_train_sc_pca, y_train)

print('최적의 하이퍼 파라미터:{0}, 최적의 평균 정확도:{1:.3f}'.format(grid_clf.best_params_, grid_clf.best_score_))
# Out:
# 최적의 하이퍼 파라미터:{'C': 0.01, 'penalty': 'l2'}, 최적의 평균 정확도:0.930
